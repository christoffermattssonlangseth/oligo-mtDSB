# %%
import scanpy as sc
import tangram as tg

# %%
ad_sp = sc.read_h5ad('../data/mtDNA_DSB_5k_clustered_LLM_anno.h5ad')
ad_sc = sc.read_h5ad('/Users/christoffer/work/karolinska/development/data/abc_atlas/combined_scRNAseq_for_tangram_subset_genes.h5ad')
tg.pp_adatas(ad_sc, ad_sp, genes=None)
# Out:
# INFO:root:5048 training genes are saved in `uns``training_genes` of both single cell and spatial Anndatas.
# INFO:root:5048 overlapped genes are saved in `uns``overlap_genes` of both single cell and spatial Anndatas.
# INFO:root:uniform based density prior is calculated and saved in `obs``uniform_density` of the spatial Anndata.
# INFO:root:rna count based density prior is calculated and saved in `obs``rna_count_based_density` of the spatial Anndata.

# %%
ad_sp.X.max()
# Out:
# 3.894839

# %%
ad_map = tg.map_cells_to_space(
                   ad_sc, 
                   ad_sp,         
                   mode='clusters',
                   cluster_label='class')
# Out:
# INFO:root:Allocate tensors for mapping.
# INFO:root:Begin training with 5048 genes and rna_count_based density_prior in clusters mode...
# INFO:root:Printing scores every 100 epochs.
# Score: 0.170, KL reg: 0.147

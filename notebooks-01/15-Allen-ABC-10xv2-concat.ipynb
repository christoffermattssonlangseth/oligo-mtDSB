# %%
import scanpy as sc
import pandas as pd
import os
import mygene
mg = mygene.MyGeneInfo()

# %%
metadata = pd.read_csv('/Users/christoffer/work/karolinska/development/data/abc_atlas/metadata/WMB-10X/20241115/cell_metadata.csv')
cluster_to_anno = pd.read_csv('/Users/christoffer/work/karolinska/development/Allen_ABC/data/abc_atlas/metadata/WMB-taxonomy/20231215/views/cluster_to_cluster_annotation_membership_pivoted.csv')
base_dir = '/Users/christoffer/work/karolinska/development/data/abc_atlas/expression_matrices/WMB-10Xv2/20230630/'
files = os.listdir(base_dir)

# %%
files = [
    'WMB-10Xv2-Isocortex-1-raw.h5ad',
    'WMB-10Xv2-OLF-raw.h5ad',
    'WMB-10Xv2-CTXsp-raw.h5ad',
    'WMB-10Xv2-TH-raw.h5ad',
    #'WMB-10Xv2-Isocortex-2-raw.h5ad',
    #'WMB-10Xv2-Isocortex-3-raw.h5ad',
    'WMB-10Xv2-MB-raw.h5ad',
    'WMB-10Xv2-HY-raw.h5ad',
    'WMB-10Xv2-HPF-raw.h5ad'
]

# %%
ad_list = []
for file in files: 
    print(file)
    ad_ = sc.read_h5ad(base_dir+file)
    ad_list.append(ad_)
# Out:
# WMB-10Xv2-Isocortex-1-raw.h5ad
# WMB-10Xv2-OLF-raw.h5ad
# WMB-10Xv2-CTXsp-raw.h5ad
# WMB-10Xv2-TH-raw.h5ad
# WMB-10Xv2-MB-raw.h5ad
# WMB-10Xv2-HY-raw.h5ad
# WMB-10Xv2-HPF-raw.h5ad

# %%
ad = sc.concat(
    ad_list,
)

# %%
ad.obs
# Out:
#                               cell_barcode       library_label  \
# cell_label
# ATTACTCCAAGTAATG-010_A01  ATTACTCCAAGTAATG  L8TX_180221_01_B11
# CATCAAGTCTGTTTGT-099_E01  CATCAAGTCTGTTTGT  L8TX_190312_01_A03
# CGATCGGAGCTCTCGG-099_A01  CGATCGGAGCTCTCGG  L8TX_190312_01_E02
# CGTGTAACAAGAAGAG-099_A01  CGTGTAACAAGAAGAG  L8TX_190312_01_E02
# TGTATTCAGCGATATA-099_C01  TGTATTCAGCGATATA  L8TX_190312_01_F02
# ...                                    ...                 ...
# TGACAACGTTCACGGC-014_F01  TGACAACGTTCACGGC  L8TX_180221_01_G12
# GCGAGAAAGTCATCCA-024_A01  GCGAGAAAGTCATCCA  L8TX_180406_01_D06
# GACACGCAGACAGACC-024_B01  GACACGCAGACAGACC  L8TX_180406_01_F06
# GTGAAGGCATGCCACG-266_A01  GTGAAGGCATGCCACG  L8TX_200625_02_E11
# TGGCGCACAGTCAGAG-266_A01  TGGCGCACAGTCAGAG  L8TX_200625_02_E11
#
#                          anatomical_division_label
# cell_label
# ATTACTCCAAGTAATG-010_A01                 Isocortex
# CATCAAGTCTGTTTGT-099_E01                 Isocortex
# CGATCGGAGCTCTCGG-099_A01                 Isocortex
# CGTGTAACAAGAAGAG-099_A01                 Isocortex
# TGTATTCAGCGATATA-099_C01                 Isocortex
# ...                                            ...
# TGACAACGTTCACGGC-014_F01                       HPF
# GCGAGAAAGTCATCCA-024_A01                       HPF
# GACACGCAGACAGACC-024_B01                       HPF
# GTGAAGGCATGCCACG-266_A01                       HPF
# TGGCGCACAGTCAGAG-266_A01                       HPF
#
# [958037 rows x 3 columns]

# %%
del ad_list

# %%
for meta in ['cluster_alias', 'donor_sex', 'dataset_label','x','y']:
    mapping_dict = dict(zip(metadata['cell_barcode'], metadata[meta]))
    ad.obs[meta] = ad.obs['cell_barcode'].map(mapping_dict)

# %%
for meta in ['neurotransmitter', 'class', 'subclass', 'supertype','cluster']:
    mapping_dict = dict(zip(cluster_to_anno['cluster_alias'], cluster_to_anno[meta]))
    ad.obs[meta] = ad.obs['cluster_alias'].map(mapping_dict)

# %%
ad.obs['class'].value_counts()
# Out:
# class
# 01 IT-ET Glut        391820
# 31 OPC-Oligo         123190
# 02 NP-CT-L6b Glut     79513
# 06 CTX-CGE GABA       70285
# 05 OB-IMN GABA        68688
# 18 TH Glut            66584
# 07 CTX-MGE GABA       62776
# 04 DG-IMN Glut        22227
# 30 Astro-Epen         19464
# 34 Immune              8774
# 33 Vascular            7618
# 12 HY GABA             7034
# 14 HY Glut             6087
# 13 CNU-HYa Glut        4227
# 19 MB Glut             4224
# 20 MB GABA             4003
# 16 HY MM Glut          2694
# 09 CNU-LGE GABA        2436
# 08 CNU-MGE GABA        1988
# 11 CNU-HYa GABA        1419
# 03 OB-CR Glut          1382
# 17 MH-LH Glut           783
# 32 OEC                  109
# 25 Pineal Glut           89
# 10 LSX GABA              37
# 24 MY Glut               19
# 21 MB Dopa               15
# 23 P Glut                13
# 27 MY GABA               12
# 26 P GABA                11
# 15 HY Gnrh1 Glut          4
# 28 CB GABA                3
# Name: count, dtype: int64

# %%
# Normalizing to median total counts
sc.pp.normalize_total(ad)
# Logarithmize the data
sc.pp.log1p(ad)

# %%
ad.write('/Users/christoffer/work/karolinska/development/data/abc_atlas/combined_scRNAseq.h5ad')

# %%
ad = sc.read_h5ad('/Users/christoffer/work/karolinska/development/data/abc_atlas/combined_scRNAseq.h5ad')

# %%
ad.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [ENSMUSG00000051951, ENSMUSG00000089699, ENSMUSG00000102331, ENSMUSG00000102343, ENSMUSG00000025900, ENSMUSG00000025902, ENSMUSG00000104238, ENSMUSG00000104328, ENSMUSG00000033845, ENSMUSG00000025903, ENSMUSG00000033813, ENSMUSG00000002459, ENSMUSG00000085623, ENSMUSG00000033793, ENSMUSG00000025905, ENSMUSG00000033774, ENSMUSG00000025907, ENSMUSG00000090031, ENSMUSG00000087247, ENSMUSG00000033740, ENSMUSG00000051285, ENSMUSG00000097797, ENSMUSG00000103067, ENSMUSG00000025909, ENSMUSG00000061024, ENSMUSG00000025911, ENSMUSG00000079671, ENSMUSG00000067879, ENSMUSG00000099827, ENSMUSG00000025912, ENSMUSG00000045210, ENSMUSG00000097893, ENSMUSG00000025915, ENSMUSG00000046101, ENSMUSG00000098234, ENSMUSG00000099032, ENSMUSG00000025916, ENSMUSG00000087199, ENSMUSG00000025917, ENSMUSG00000056763, ENSMUSG00000067851, ENSMUSG00000042501, ENSMUSG00000048960, ENSMUSG00000057715, ENSMUSG00000097171, ENSMUSG00000101314, ENSMUSG00000016918, ENSMUSG00000025938, ENSMUSG00000099498, ENSMUSG00000042414, ENSMUSG00000005886, ENSMUSG00000101476, ENSMUSG00000025935, ENSMUSG00000025937, ENSMUSG00000067813, ENSMUSG00000025932, ENSMUSG00000054493, ENSMUSG00000025930, ENSMUSG00000032769, ENSMUSG00000092083, ENSMUSG00000025925, ENSMUSG00000032719, ENSMUSG00000067795, ENSMUSG00000043716, ENSMUSG00000025921, ENSMUSG00000100868, ENSMUSG00000025920, ENSMUSG00000089982, ENSMUSG00000025939, ENSMUSG00000079658, ENSMUSG00000097744, ENSMUSG00000025940, ENSMUSG00000025779, ENSMUSG00000101640, ENSMUSG00000042686, ENSMUSG00000100110, ENSMUSG00000025777, ENSMUSG00000099899, ENSMUSG00000067780, ENSMUSG00000100053, ENSMUSG00000085125, ENSMUSG00000025776, ENSMUSG00000099895, ENSMUSG00000109887, ENSMUSG00000025774, ENSMUSG00000073735, ENSMUSG00000067773, ENSMUSG00000089787, ENSMUSG00000042596, ENSMUSG00000025927, ENSMUSG00000100538, ENSMUSG00000043760, ENSMUSG00000089914, ENSMUSG00000099906, ENSMUSG00000025929, ENSMUSG00000041872, ENSMUSG00000041859, ENSMUSG00000102121, ENSMUSG00000097934, ENSMUSG00000025931, ...]
#
# [32285 rows x 0 columns]

# %%
ad_sp = sc.read_h5ad('../data/mtDNA_DSB_5k_clustered_LLM_anno.h5ad')
# Out:
# /Users/christoffer/miniconda3/envs/sc/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
import re
import pandas as pd
from pathlib import Path

def load_ensembl_gene_map(gtf_path):
    """
    Parse an Ensembl GTF and return a dict: {ensembl_gene_id: gene_symbol}.
    Keeps only 'gene' features; strips version suffixes.
    """
    gene_map = {}
    pat_id   = re.compile(r'gene_id "([^"]+)"')
    pat_name = re.compile(r'gene_name "([^"]+)"')
    with open(gtf_path, "r") as fh:
        for line in fh:
            if line.startswith("#"): 
                continue
            # Only keep 'gene' feature lines to avoid huge memory use
            # GTF columns: seqname, source, feature, start, end, score, strand, frame, attributes
            parts = line.rstrip("\n").split("\t")
            if len(parts) < 9 or parts[2] != "gene":
                continue
            attrs = parts[8]
            m_id = pat_id.search(attrs)
            m_nm = pat_name.search(attrs)
            if not (m_id and m_nm):
                continue
            gid = m_id.group(1).split('.')[0]   # strip version, e.g. ENSMUSG... .1 → base
            gnm = m_nm.group(1)
            # keep first occurrence (usually fine). If you want, prefer protein_coding using parts[1]/attrs
            if gid not in gene_map:
                gene_map[gid] = gnm
    return gene_map

# %%
# --- use it ---
# Point to your Mus musculus Ensembl GTF (e.g., Mus_musculus.GRCm39.109.gtf)
gtf_file = "//Users/christoffer/Downloads/Mus_musculus.GRCm39.109.gtf"
gene_map = load_ensembl_gene_map(gtf_file)

# ids_to_map: list/Series/Index of 32,285 Ensembl IDs (with/without version)
def map_ids_to_symbols(ids, gene_map):
    # vectorized mapping via pandas for speed and NaN handling
    s = pd.Series(ids, dtype="string")
    base = s.str.replace(r"\.\d+$", "", regex=True)  # strip version suffixes
    symbols = base.map(gene_map).astype("string")
    return symbols.tolist()

# Example:
# ids_to_map = adata.var_names.tolist()
# symbols = map_ids_to_symbols(ids_to_map, gene_map)
#

# %%
ids_to_map = ad.var_names.tolist()

# %%
symbols = map_ids_to_symbols(ids_to_map, gene_map)

# %%
ad.var["gene_symbol"] = symbols

# %%
ad.var = ad.var.set_index('gene_symbol')

# %%
ad._inplace_subset_var(~ad.var.index.isna())
# Out:
# /Users/christoffer/miniconda3/envs/sc/lib/python3.8/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /Users/christoffer/miniconda3/envs/sc/lib/python3.8/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
common_genes = ad.var_names.intersection(ad_sp.var_names)

# %%
ad_sp_sub = ad_sp[:, common_genes]

# %%
ad.var_names_make_unique()  # in-place; appends -1, -2, ...

# %%
ad_sp_sub = ad_sp[:, common_genes]
ad_sub = ad[:, common_genes]

# %%
ad_sub.write('/Users/christoffer/work/karolinska/development/data/abc_atlas/combined_scRNAseq_for_tangram_subset_genes.h5ad')

# %%
import pandas as pd

# make sure var_names are string, replace NaN with something safe
ad.var_names = pd.Index(ad.var_names.astype(str))
ad_sp.var_names = pd.Index(ad_sp.var_names.astype(str))

# %%
# optionally drop "nan" entries
ad = ad[:, ad.var_names != '<NA>'].copy()
ad_sp = ad_sp[:, ad_sp.var_names != "nan"].copy()

# %%
common_genes = ad.var_names.intersection(ad_sp.var_names)

ad_sub    = ad[:, common_genes].copy()
ad_sp_sub = ad_sp[:, common_genes].copy()

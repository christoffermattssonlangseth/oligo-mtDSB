# %%
import pandas as pd
from pathlib import Path
import numpy as np
import anndata
import time

from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache

# %%
download_base = Path('../../data/abc_atlas')
abc_cache = AbcProjectCache.from_cache_dir(download_base)

abc_cache.current_manifest
# Out:
# 'releases/20250531/manifest.json'

# %%
cell = abc_cache.get_metadata_dataframe(directory='WMB-10Xv2', file_name='cell_metadata')
cell.set_index('cell_label', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cell = abc_cache.get_metadata_dataframe(directory='WMB-10Xv2', file_name='cell_metadata')
#       2 cell.set_index('cell_label', inplace=True)
#
# File ~/miniconda3/envs/sc/lib/python3.8/site-packages/abc_atlas_access/abc_atlas_cache/abc_project_cache.py:423, in AbcProjectCache.get_metadata_dataframe(self, directory, file_name, force_download, skip_hash_check, **kwargs)
#     392 def get_metadata_dataframe(
#     393         self,
#     394         directory: str,
#    (...)
#     398         **kwargs
#     399 ) -> pd.DataFrame:
#     400     """
#     401     Get the metadata table with the given file name. Download the file if
#     402     using a S3Cache and the file is not currently on disk.
#    (...)
#     421         Dataframe of the requested metadata file.
#     422     """
# --> 423     path = self.get_metadata_path(
#     424         directory=directory,
#     425         file_name=file_name,
#     426         force_download=force_download,
#     427         skip_hash_check=skip_hash_check
#     428     )
#     429     return pd.read_csv(path, **kwargs)
#
# File ~/miniconda3/envs/sc/lib/python3.8/site-packages/abc_atlas_access/abc_atlas_cache/abc_project_cache.py:466, in AbcProjectCache.get_metadata_path(self, directory, file_name, force_download, skip_hash_check)
#     460     path = self._get_local_path(
#     461         directory=directory,
#     462         file_name=file_name,
#     463         is_metadata=True
#     464     )
#     465 else:
# --> 466     path = self.cache.download_metadata(
#     467         directory=directory,
#     468         file_name=file_name,
#     469         force_download=force_download,
#     470         skip_hash_check=skip_hash_check
#     471     )
#     472 return path
#
# File ~/miniconda3/envs/sc/lib/python3.8/site-packages/abc_atlas_access/abc_atlas_cache/cloud_cache.py:883, in CloudCacheBase.download_metadata(self, directory, file_name, force_download, skip_hash_check)
#     851 def download_metadata(self,
#     852                       directory: str,
#     853                       file_name: str,
#     854                       force_download: bool = False,
#     855                       skip_hash_check: bool = False) -> Path:
#     856     """
#     857     Return the local path to a metadata file, downloading the
#     858     file if necessary
#    (...)
#     881         If the file cannot be downloaded
#     882     """
# --> 883     super_attributes = self.metadata_path(
#     884         directory=directory, file_name=file_name)
#     885     # If the file exists, check that it was downloaded successfully.
#     886     if super_attributes['exists'] \
#     887             and not self._check_successful_download(
#     888                 file_attributes=super_attributes['file_attributes']):
#
# File ~/miniconda3/envs/sc/lib/python3.8/site-packages/abc_atlas_access/abc_atlas_cache/cloud_cache.py:370, in BasicLocalCache.metadata_path(self, directory, file_name)
#     341 def metadata_path(self, directory: str, file_name: str) -> dict:
#     342     """
#     343     Return the local path to a metadata file, and test for the
#     344     file's existence
#    (...)
#     368         If the file cannot be downloaded
#     369     """
# --> 370     output = self._get_file_path(directory=directory, file_name=file_name)
#     372     return output
#
# File ~/miniconda3/envs/sc/lib/python3.8/site-packages/abc_atlas_access/abc_atlas_cache/cloud_cache.py:329, in BasicLocalCache._get_file_path(self, directory, file_name)
#     300 def _get_file_path(self, directory: str, file_name: str) -> dict:
#     301     """
#     302     Return the local path to a data file, and test for the
#     303     file's existence.
#    (...)
#     327         If the file cannot be downloaded
#     328     """
# --> 329     file_attributes = self._manifest.get_file_attributes(
#     330         directory=directory,
#     331         file_name=file_name
#     332     )
#     333     exists = self._file_exists(file_attributes)
#     334     local_path = file_attributes.local_path
#
# File ~/miniconda3/envs/sc/lib/python3.8/site-packages/abc_atlas_access/abc_atlas_cache/manifest.py:245, in Manifest.get_file_attributes(self, directory, file_name)
#     238             raise KeyError(
#     239                 f"File {file_name} found in directory but multiple "
#     240                 f"files found: {list(files_data.keys())}. Please "
#     241                 "specify the file name as one of "
#     242                 f"{['%s/%s' % (file_name, key) for key in files_data.keys()]}"  # noqa: E501
#     243             )
#     244 if file_attributes is None:
# --> 245     raise KeyError(
#     246         f"File {file_name} not found in directory {directory}."
#     247     )
#     249 return file_attributes
#
# KeyError: 'File cell_metadata not found in directory WMB-10Xv2.'

# %%
matrices = cell.groupby(['dataset_label', 'feature_matrix_label'])[['library_label']].count()
matrices.columns  = ['cell_count']
matrices

# %%
files = abc_cache.list_data_files('WMB-10Xv2')
print(files)
# Out:
# ['WMB-10Xv2-CTXsp/log2', 'WMB-10Xv2-CTXsp/raw', 'WMB-10Xv2-HPF/log2', 'WMB-10Xv2-HPF/raw', 'WMB-10Xv2-HY/log2', 'WMB-10Xv2-HY/raw', 'WMB-10Xv2-Isocortex-1/log2', 'WMB-10Xv2-Isocortex-1/raw', 'WMB-10Xv2-Isocortex-2/log2', 'WMB-10Xv2-Isocortex-2/raw', 'WMB-10Xv2-Isocortex-3/log2', 'WMB-10Xv2-Isocortex-3/raw', 'WMB-10Xv2-Isocortex-4/log2', 'WMB-10Xv2-Isocortex-4/raw', 'WMB-10Xv2-MB/log2', 'WMB-10Xv2-MB/raw', 'WMB-10Xv2-OLF/log2', 'WMB-10Xv2-OLF/raw', 'WMB-10Xv2-TH/log2', 'WMB-10Xv2-TH/raw']

# %%
files
# Out:
# ['WMB-10Xv2-CTXsp/log2',
#  'WMB-10Xv2-CTXsp/raw',
#  'WMB-10Xv2-HPF/log2',
#  'WMB-10Xv2-HPF/raw',
#  'WMB-10Xv2-HY/log2',
#  'WMB-10Xv2-HY/raw',
#  'WMB-10Xv2-Isocortex-1/log2',
#  'WMB-10Xv2-Isocortex-1/raw',
#  'WMB-10Xv2-Isocortex-2/log2',
#  'WMB-10Xv2-Isocortex-2/raw',
#  'WMB-10Xv2-Isocortex-3/log2',
#  'WMB-10Xv2-Isocortex-3/raw',
#  'WMB-10Xv2-Isocortex-4/log2',
#  'WMB-10Xv2-Isocortex-4/raw',
#  'WMB-10Xv2-MB/log2',
#  'WMB-10Xv2-MB/raw',
#  'WMB-10Xv2-OLF/log2',
#  'WMB-10Xv2-OLF/raw',
#  'WMB-10Xv2-TH/log2',
#  'WMB-10Xv2-TH/raw']

# %%
files = [
 'WMB-10Xv2-OLF/log2',
 'WMB-10Xv2-OLF/raw',
 'WMB-10Xv2-TH/log2',
 'WMB-10Xv2-TH/raw']

# %%
for file in files: 
    if 'raw' in file:
        print('get this file')
        print(file)
        abc_cache.get_data_path(directory='WMB-10Xv2', file_name=file)
# Out:
# get this file
# WMB-10Xv2-OLF/raw
# WMB-10Xv2-OLF-raw.h5ad:   5%|▋             | 246M/5.13G [01:02<39:06, 2.08MMB/s]

# %%
cell = abc_cache.get_metadata_dataframe(directory='WMB-10Xv2', file_name='cell_metadata')
cell.set_index('cell_label', inplace=True)

# %%
ad = anndata.read_h5ad(file,backed='r')
gene = ad.var

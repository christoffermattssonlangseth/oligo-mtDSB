# %%
import scanpy as sc

# %%
ad = sc.read_h5ad('../data/integrated_clustered.h5ad')

# %%
ad.obs
# Out:
#                    x_centroid   y_centroid  transcript_counts  \
# cell_id
# aaadgfgj-1-RRmap   181.586823  1630.103394                474
# aaaeckib-1-RRmap   212.154877  1685.950928                882
# aaaemkgl-1-RRmap   235.259537  1613.899048               1561
# aaagfkdi-1-RRmap   213.706497  1525.154907               1403
# aaagghkg-1-RRmap   196.850647  1526.920288                785
# ...                       ...          ...                ...
# oifndkbo-1-mtDSB  2379.717529  4785.681152                419
# oifolalk-1-mtDSB  2281.881104  4803.725098                219
# oifphdni-1-mtDSB  2343.403564  4830.252441                 76
# oigabhlk-1-mtDSB  2341.813477  4843.651367                176
# oigafpoe-1-mtDSB  2280.780273  4669.423828                 70
#
#                   control_probe_counts  genomic_control_counts  \
# cell_id
# aaadgfgj-1-RRmap                     0                       0
# aaaeckib-1-RRmap                     0                       0
# ...

# %%
ad
